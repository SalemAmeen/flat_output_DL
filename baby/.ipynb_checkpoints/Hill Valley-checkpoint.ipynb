#
# [10 rows x 101 columns]
# ===============================================
#              X1            X2            X3            X4            X5  \
# 0   1041.990593   1039.850024   1037.136237   1033.695733   1029.333904
# 1     62.191641     62.191641     62.191640     62.191640     62.191640
# 2   3216.305785   3216.305745   3216.305698   3216.305642   3216.305575
# 3   6373.569435   6373.015068   6372.300869   6371.380752   6370.195350
# 4     16.680583     16.699414     16.723735     16.755150     16.795726
# 5    556.899589    556.899193    556.898703    556.898097    556.897349
# 6      1.276645      1.277020      1.277487      1.278067      1.278789
# 7  26906.815760  26907.343230  26908.010280  26908.853870  26909.920700
# 8   7620.673487   7620.673484   7620.673480   7620.673474   7620.673467
# 9    198.096368    198.096381    198.096397    198.096415    198.096438
#
#              X6            X7            X8            X9           X10  \
# 0   1023.804033   1016.793331   1007.905251    996.637055    982.351378
# 1     62.191639     62.191639     62.191638     62.191637     62.191636
# 2   3216.305494   3216.305398   3216.305284   3216.305147   3216.304983
# 3   6368.668175   6366.700689   6364.165942   6360.900382   6356.693303
# 4     16.848135     16.915828     17.003263     17.116196     17.262063
# 5    556.896424    556.895282    556.893869    556.892123    556.889966
# 6      1.279687      1.280804      1.282193      1.283920      1.286068
# 7  26911.269860  26912.976060  26915.133780  26917.862520  26921.313390
# 8   7620.673458   7620.673446   7620.673431   7620.673412   7620.673386
# 9    198.096464    198.096496    198.096534    198.096580    198.096634
#
#    ...             X92           X93           X94           X95  \
# 0  ...     1049.984130   1049.984130   1049.984130   1049.984130
# 1  ...       61.620700     61.738466     61.831941     61.906135
# 2  ...     2471.695866   2593.019302   2694.574841   2779.583376
# 3  ...     6375.492097   6375.492119   6375.492136   6375.492150
# 4  ...       16.616014     16.616014     16.616014     16.616014
# 5  ...      556.889966    556.892123    556.893869    556.895282
# 6  ...        1.275105      1.275105      1.275105      1.275105
# 7  ...    26904.859410  26904.851710  26904.845620  26904.840800
# 8  ...     7605.456514   7608.905193   7611.572286   7613.634926
# 9  ...      211.734439    209.522912    207.670001    206.117553
#
#             X96           X97           X98           X99          X100  class
# 0   1049.984130   1049.984130   1049.984130   1049.984130   1049.984130      0
# 1     61.965026     62.011769     62.048871     62.078320     62.101694      0
# 2   2850.741001   2910.304521   2960.163029   3001.897815   3036.832521      0
# 3   6375.492160   6375.492168   6375.492174   6375.492179   6375.492183      0
# 4     16.616014     16.616014     16.616014     16.616014     16.616014      1
# 5    556.896424    556.897349    556.898097    556.898703    556.899193      0
# 6      1.275105      1.275105      1.275105      1.275105      1.275105      1
# 7  26904.836990  26904.833970  26904.831590  26904.829710  26904.828220      1
# 8   7615.230103   7616.463759   7617.417827   7618.155671   7618.726295      0
# 9    204.816846    203.727059    202.813989    202.048980    201.408023      1
#
# [10 rows x 101 columns]

# %%
shape = data.shape
print(shape)
# Out:
# (606, 101)

# %%
types = data.dtypes
print(types)
# Out:
# X1       float64
# X2       float64
# X3       float64
# X4       float64
# X5       float64
# X6       float64
# X7       float64
# X8       float64
# X9       float64
# X10      float64
# X11      float64
# X12      float64
# X13      float64
# X14      float64
# X15      float64
# X16      float64
# X17      float64
# X18      float64
# X19      float64
# X20      float64
# X21      float64
# X22      float64
# X23      float64
# X24      float64
# X25      float64
# X26      float64
# X27      float64
# X28      float64
# X29      float64
# X30      float64
#           ...
# X72      float64
# X73      float64
# X74      float64
# X75      float64
# X76      float64
# X77      float64
# X78      float64
# X79      float64
# X80      float64
# X81      float64
# X82      float64
# X83      float64
# X84      float64
# X85      float64
# X86      float64
# X87      float64
# X88      float64
# X89      float64
# X90      float64
# X91      float64
# X92      float64
# X93      float64
# X94      float64
# X95      float64
# X96      float64
# X97      float64
# X98      float64
# X99      float64
# X100     float64
# class      int64
# dtype: object

# %%
pandas.set_option('display.width', 100)
pandas.set_option('precision', 3)
description = data.describe()
print(description)
# Out:
#                X1          X2          X3          X4          X5          X6          X7  \
# count     606.000     606.000     606.000     606.000     606.000     606.000     606.000
# mean     8323.021    8320.480    8317.422    8313.742    8309.318    8304.003    8297.622
# std     18928.879   18922.278   18914.376   18904.986   18893.933   18881.089   18866.427
# min         0.914       0.914       0.914       0.914       0.914       0.914       0.914
# 25%        17.858      17.857      17.851      17.843      17.833      17.820      17.804
# 50%       300.777     300.846     300.846     300.846     300.847     300.847     300.847
# 75%      5110.866    5110.862    5110.857    5110.850    5110.843    5110.834    5110.823
# max    115445.843  115445.773  115445.691  115445.594  115445.479  115445.344  115445.185
#
#                X8          X9         X10   ...            X92         X93         X94  \
# count     606.000     606.000     606.000   ...        606.000     606.000     606.000
# mean     8289.967    8280.794    8269.811   ...       8354.945    8351.338    8348.391
# std     18850.121   18832.695   18815.274   ...      19027.059   19012.417   19001.099
# min         0.914       0.914       0.914   ...          0.922       0.921       0.920
# 25%        17.776      17.703      17.649   ...         17.883      17.792      17.574
# 50%       300.848     300.849     300.850   ...        300.441     300.439     300.437
# 75%      5110.809    5110.793    5110.774   ...       5106.900    5116.292    5137.235
# max    115444.996  115659.181  116160.368   ...     112967.942  113345.571  113665.659
#
#               X95         X96         X97         X98         X99        X100    class
# count     606.000     606.000     606.000     606.000     606.000     606.000  606.000
# mean     8345.984    8344.018    8342.414    8341.105    8340.037    8339.166    0.497
# std     18992.295   18985.412   18980.007   18975.747   18972.382   18969.716    0.500
# min         0.919       0.918       0.918       0.917       0.917       0.916    0.000
# 25%        17.574      17.646      17.794      17.838      17.874      17.882    0.000
# 50%       300.436     300.435     300.434     300.433     300.433     300.433    0.000
# 75%      5155.527    5163.506    5152.222    5142.624    5134.461    5127.518    1.000
# max    113936.973  114166.946  114361.877  114527.105  114667.156  114785.868    1.000
#
# [8 rows x 101 columns]

# %%
class_counts = data.groupby('class').size() # 1 is the class atribute in the dataset
print(class_counts)
# Out:
# class
# 0    305
# 1    301
# dtype: int64

# %%
correlations = data.corr(method='pearson')
print(correlations)
# Out:
#           X1     X2     X3     X4     X5     X6     X7     X8     X9    X10  ...      X92    X93  \
# X1     1.000  1.000  1.000  1.000  1.000  1.000  1.000  0.999  0.999  0.998  ...    0.999  1.000
# X2     1.000  1.000  1.000  1.000  1.000  1.000  1.000  0.999  0.999  0.998  ...    0.999  1.000
# X3     1.000  1.000  1.000  1.000  1.000  1.000  1.000  0.999  0.999  0.998  ...    0.999  1.000
# X4     1.000  1.000  1.000  1.000  1.000  1.000  1.000  1.000  0.999  0.998  ...    0.999  0.999
# X5     1.000  1.000  1.000  1.000  1.000  1.000  1.000  1.000  0.999  0.999  ...    0.999  0.999
# X6     1.000  1.000  1.000  1.000  1.000  1.000  1.000  1.000  1.000  0.999  ...    0.999  0.999
# X7     1.000  1.000  1.000  1.000  1.000  1.000  1.000  1.000  1.000  0.
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# X72    0.989  0.989  0.989  0.989  0.989  0.988  0.988 -0.021
# X73    0.986  0.986  0.986  0.986  0.985  0.985  0.985 -0.020
# X74    0.990  0.990  0.990  0.989  0.989  0.989  0.989 -0.022
# X75    0.992  0.992  0.992  0.992  0.992  0.992  0.992 -0.023
# X76    0.994  0.994  0.994  0.994  0.994  0.993  0.993 -0.023
# X77    0.995  0.995  0.995  0.995  0.995  0.995  0.995 -0.024
# X78    0.996  0.996  0.995  0.995  0.995  0.995  0.995 -0.024
# X79    0.995  0.995  0.995  0.995  0.995  0.995  0.995 -0.024
# X80    0.996  0.996  0.996  0.996  0.996  0.996  0.996 -0.024
# X81    0.997  0.997  0.997  0.997  0.997  0.997  0.997 -0.025
# X82    0.997  0.997  0.997  0.997  0.997  0.997  0.997 -0.026
# X83    0.998  0.998  0.998  0.998  0.998  0.998  0.997 -0.028
# X84    0.999  0.999  0.998  0.998  0.998  0.998  0.998 -0.029
# X85    0.999  0.999  0.999  0.999  0.999  0.999  0.999 -0.030
# X86    0.999  0.999  0.999  0.999  0.999  0.999  0.999 -0.031
# X87    0.999  0.999  0.999  0.999  0.999  0.999  0.999 -0.032
# X88    0.999  0.999  0.999  0.999  0.998  0.998  0.998 -0.032
# X89    0.999  0.999  0.999  0.999  0.999  0.999  0.999 -0.033
# X90    1.000  1.000  0.999  0.999  0.999  0.999  0.999 -0.035
# X91    1.000  1.000  1.000  1.000  1.000  1.000  0.999 -0.036
# X92    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.037
# X93    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.038
# X94    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.039
# X95    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.039
# X96    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.040
# X97    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.040
# X98    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.041
# X99    1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.041
# X100   1.000  1.000  1.000  1.000  1.000  1.000  1.000 -0.041
# class -0.039 -0.039 -0.040 -0.040 -0.041 -0.041 -0.041  1.000
#
# [101 rows x 101 columns]

# %%
skew = data.skew()
print(skew)
# Out:
# X1       3.086
# X2       3.087
# X3       3.088
# X4       3.089
# X5       3.090
# X6       3.092
# X7       3.094
# X8       3.098
# X9       3.103
# X10      3.110
# X11      3.119
# X12      3.112
# X13      3.108
# X14      3.112
# X15      3.121
# X16      3.136
# X17      3.151
# X18      3.169
# X19      3.188
# X20      3.213
# X21      3.222
# X22      3.241
# X23      3.274
# X24      3.318
# X25      3.351
# X26      3.400
# X27      3.470
# X28      3.417
# X29      3.400
# X30      3.323
#          ...
# X72      3.234
# X73      3.304
# X74      3.229
# X75      3.176
# X76      3.139
# X77      3.112
# X78      3.094
# X79      3.083
# X80      3.077
# X81      3.075
# X82      3.076
# X83      3.076
# X84      3.075
# X85      3.077
# X86      3.081
# X87      3.086
# X88      3.094
# X89      3.084
# X90      3.081
# X91      3.080
# X92      3.079
# X93      3.079
# X94      3.079
# X95      3.079
# X96      3.080
# X97      3.080
# X98      3.080
# X99      3.081
# X100     3.081
# class    0.013
# dtype: float64

# %%
data.head()
# Out:
#           X1         X2         X3         X4         X5         X6         X7         X8  \
# 0   1317.266   1315.221   1312.771   1309.834   1306.316   1302.099   1297.046   1290.992
# 1   7329.968   7379.907   7441.799   7518.503   7613.565   7731.377   7877.386   8058.338
# 2    809.421    809.780    810.207    810.716    811.321    812.042    812.900    813.921
# 3  45334.209  45334.214  45334.219  45334.226  45334.233  45334.242  45334.252  45334.264
# 4      1.810      1.810      1.810      1.810      1.810      1.810      1.810      1.810
#
#           X9        X10  ...          X92        X93        X94        X95        X96        X97  \
# 0   1283.736   1275.042  ...     1327.575   1327.575   1327.576   1327.576   1327.576   1327.576
# 1   8282.596   8560.526  ...     7121.300   7121.300   7121.300   7121.300   7121.300   7121.300
# 2    815.138    816.586  ...      807.545    807.544    807.543    807.543    807.542    807.542
# 3  45334.279  45334.296  ...    47550.922  47224.458  46946.073  46708.686  46506.260  46333.646
# 4      1.810      1.810  ...        1.790      1.795      1.798      1.801      1.803      1.805
#
#          X98        X99       X100  class
# 0   1327.576   1327.576   1327.576      0
# 1   7121.300   7121.300   7121.300      1
# 2    807.541    807.541    807.541      1
# 3  46186.452  46060.937  45953.906      1
# 4      1.806      1.807      1.808      0
#
# [5 rows x 101 columns]

# %%
data.head()
# Out:
#           X1         X2         X3         X4         X5         X6         X7         X8  \
# 0   1317.266   1315.221   1312.771   1309.834   1306.316   1302.099   1297.046   1290.992
# 1   7329.968   7379.907   7441.799   7518.503   7613.565   7731.377   7877.386   8058.338
# 2    809.421    809.780    810.207    810.716    811.321    812.042    812.900    813.921
# 3  45334.209  45334.214  45334.219  45334.226  45334.233  45334.242  45334.252  45334.264
# 4      1.810      1.810      1.810      1.810      1.810      1.810      1.810      1.810
#
#           X9        X10  ...          X92        X93        X94        X95        X96        X97  \
# 0   1283.736   1275.042  ...     1327.575   1327.575   1327.576   1327.576   1327.576   1327.576
# 1   8282.596   8560.526  ...     7121.300   7121.300   7121.300   7121.300   7121.300   7121.300
# 2    815.138    816.586  ...      807.545    807.544    807.543    807.543    807.542    807.542
# 3  45334.279  45334.296  ...    47550.922  47224.458  46946.073  46708.686  46506.260  46333.646
# 4      1.810      1.810  ...        1.790      1.795      1.798      1.801      1.803      1.805
#
#          X98        X99       X100  class
# 0   1327.576   1327.576   1327.576      0
# 1   7121.300   7121.300   7121.300      1
# 2    807.541    807.541    807.541      1
# 3  46186.452  46060.937  45953.906      1
# 4      1.806      1.807      1.808      0
#
# [5 rows x 101 columns]

# %% [markdown]
# # Visulize the data

# %%
data.hist()
plt.show()

# %% [markdown]
# # Prepare the data for classification

# %%
from sklearn import preprocessing
# for training data
dataset = data.values
X = dataset[:,0:100].astype(float)
Y = dataset[:,100]
features = preprocessing.scale(X)
target = Y

# %%
# for testing data
datasetTest = test.values
X = datasetTest[:,0:100].astype(float)
Y = datasetTest[:,100]
X_deploy = preprocessing.scale(X)
y_deploy = Y

# %% [markdown]
# # Feature Selection

# %%
from sklearn.cross_validation import train_test_split
# Extracting 20% validation data
X_train, X_test, y_train, y_test = train_test_split(
    features, target, test_size=0.20, random_state=17)

# %%
from sklearn import metrics
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier()
model.fit(X_train, y_train)
# display the relative importance of each attribute
print(model.feature_importances_)
# Out:
# [ 0.01396099  0.00886943  0.01087071  0.01011085  0.00967262  0.01160739
#   0.01284749  0.00830518  0.00969217  0.0073807   0.00861169  0.00771996
#   0.00649181  0.00663513  0.01119772  0.00401049  0.01430104  0.00990473
#   0.01301248  0.01043337  0.01205355  0.01153958  0.00942997  0.01042226
#   0.01114148  0.01274123  0.01028003  0.01354849  0.01230502  0.00823158
#   0.00878511  0.01164454  0.00583635  0.00736973  0.00761041  0.01028124
#   0.00978619  0.0068512   0.00513576  0.01021587  0.01013087  0.00950891
#   0.00783524  0.01267198  0.01198689  0.01085043  0.00894285  0.01169868
#   0.00908948  0.01080943  0.00908654  0.013758    0.01538423  0.00858643
#   0.00699682  0.00775695  0.01105277  0.01338097  0.00932789  0.00757628
#   0.01179287  0.01154438  0.01171263  0.01161789  0.01288819  0.01308673
#   0.01032214  0.01046004  0.00993485  0.00521261  0.00991054  0.00944378
#   0.01398093  0.00596015  0.01608874  0.01016884  0.01393694  0.00811515
#   0.00981877  0.00623685  0.0082129   0.00890771  0.0097982   0.01090985
#   0.00828583  0.01120312  0.00848397  0.0079639   0.00868533  0.00798176
#   0.00532865  0.0104308   0.01417177  0.00920839  0.01334944  0.00923735
#   0.01006627  0.01039526  0.00959819  0.00827107]

# %%
# importabt of features according to random forest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators = 15)
rf.fit(X_train, y_train)
imp = rf.feature_importances_
names = data.columns

imp, names = zip(*sorted(zip(imp,names)))
plt.barh(range(len(names)), imp, align = 'center')
plt.yticks(range(len(names)), names)
plt.rcParams['figure.figsize'] = (15, 20)
plt.xlabel('Impotance of features')
plt.ylabel('features')
plt.title('Importance of each feature')
plt.show()

# %% [markdown]
# ## Preproccing

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
# create the RFE model and select 5 attributes
rfe = RFE(model, 5)
rfe = rfe.fit(X_train, y_train)
# summarize the selection of the attributes
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [ True False False False False False False False False False False False
#  False False False False False  True False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False  True False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True  True]
# [ 1  8 12 14 19 27 38 46 68 83 39 45 50 15 26 33 20  1  4 11 30 24 41  2 47
#  18 36 60 69 84 76 79 92 90 72 53 89 96 93 94 85 80 63 42 28  9 71 88 95 91
#  66 57 44 21 74 70 78 81 65 55 31 40  7 17 48 54 59 62 25  1 37 56 73 87 82
#  75 77 64 43  5 13 23 35 49 58 61 52 32 86 67 51 34 29 22 16 10  6  3  1  1]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=10)
pca.fit(X_train)
print(pca.explained_variance_ratio_)
# Out:
# [  9.95390460e-01   1.37409572e-03   9.26339254e-04   5.55413229e-04
#    4.72577845e-04   3.64195778e-04   2.55106197e-04   1.78850838e-04
#    1.25402213e-04   8.57601333e-05]

# %%
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)
X_deploy = pca.transform(X_deploy)

# %%
print 'Number of training examples',len(X_train)
print 'Number of validation examples',len(X_test)
print 'Number of testing examples',len(X_deploy)
# Out:
# Number of training examples 484
# Number of validation examples 122
# Number of testing examples 606

# %%
from sklearn import preprocessing
# normalize the data attributes
X_train = preprocessing.normalize(X_train)
X_test = preprocessing.normalize(X_test)
X_deploy = preprocessing.normalize(X_deploy)
# standardize the data attributes
X_train = preprocessing.scale(X_train)
X_test = preprocessing.scale(X_test)
X_deploy = preprocessing.scale(X_deploy)

# %% [markdown]
# # Building classifiers

# %% [markdown]
# ## KNN classifier
# It turns out that k=5 is the best choose of k on the validation set

# %%
from sklearn.neighbors import KNeighborsClassifier
clf_neigh = KNeighborsClassifier(n_neighbors=5)
plt.rcParams['figure.figsize'] = (6, 4)
#Training
start_time = time.time()
clf_neigh.fit(X_train, y_train)
print("The time for training KNN is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_neigh.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['B', 'M'])
print "==================================================================="
print "The accuracy on validation dataset of KNN: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of KNN:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of KNN :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of KNN:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training KNN is  0.000999927520752 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           B       0.59      0.96      0.73        54
#           M       0.94      0.47      0.63        68
#
# avg / total       0.79      0.69      0.67       122
#
# ===================================================================
# The accuracy on validation dataset of KNN: 	0.688524590164
# Precision on validation dataset of KNN:    	0.941176470588
# Recall on validation dataset of KNN :      	0.470588235294
# F1 score on validation dataset of KNN:     	0.627450980392

# %% [markdown]
# ## SVM classifier
# ### Linear SVM "LinearSVC"
# It turns out that C=20 is the best on the validation set

# %%
from sklearn.svm import LinearSVC
clf_svm_linear = LinearSVC(C=20.0)
#Training
start_time = time.time()
clf_svm_linear.fit(X_train, y_train)
print("The time for training SVM is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_svm_linear.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Linear SVM: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Linear SVM:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Linear SVM :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Linear SVM:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training SVM is  0.0190000534058 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.53      0.98      0.69        54
#           B       0.95      0.31      0.47        68
#
# avg / total       0.77      0.61      0.56       122
#
# ===================================================================
# The accuracy on validation dataset of Linear SVM: 	0.606557377049
# Precision on validation dataset of Linear SVM:    	0.954545454545
# Recall on validation dataset of Linear SVM :      	0.308823529412
# F1 score on validation dataset of Linear SVM:     	0.466666666667

# %% [markdown]
# ###  SVM "SVC" with kernel='rbf'

# %%
from sklearn.svm import SVC
clf_svm = SVC(kernel='rbf')
#Training
start_time = time.time()
clf_svm.fit(X_train, y_train)
print("The time for training SVM is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_svm.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of SVM: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of SVM:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of SVM :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of SVM:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training SVM is  0.00799989700317 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.52      1.00      0.68        54
#           B       1.00      0.26      0.42        68
#
# avg / total       0.79      0.59      0.54       122
#
# ===================================================================
# The accuracy on validation dataset of SVM: 	0.590163934426
# Precision on validation dataset of SVM:    	1.0
# Recall on validation dataset of SVM :      	0.264705882353
# F1 score on validation dataset of SVM:     	0.418604651163

# %% [markdown]
# ## Decsion Tree classifier
# ### DT with Gini impurity "gini", CART (Classification and Regression Trees)
# It turns out that min_samples_split=2 is the best on the validation set

# %%
# CART tree
from sklearn.tree import DecisionTreeClassifier
clf_dt = DecisionTreeClassifier(min_samples_split=2)
#Training
start_time = time.time()
clf_dt.fit(X_train, y_train)
print("The time for training Decision Tree is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Decision Tree: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Decision Tree:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Decision Tree :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Decision Tree:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Decision Tree is  0.0019998550415 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.76      0.35      0.48        54
#           B       0.64      0.91      0.75        68
#
# avg / total       0.69      0.66      0.63       122
#
# ===================================================================
# The accuracy on validation dataset of Decision Tree: 	0.66393442623
# Precision on validation dataset of Decision Tree:    	0.639175257732
# Recall on validation dataset of Decision Tree :      	0.911764705882
# F1 score on validation dataset of Decision Tree:     	0.751515151515

# %% [markdown]
# ### DT with “entropy” for the information gain, C4.5 (aka J48 is an open source Java Weka) and C5.0
# It turns out that min_samples_split=2 is the best on the validation set

# %%
# Here I use C5.0 tree as its more accurate that C4.5 and more recent.
from sklearn.tree import DecisionTreeClassifier
clf_dt_IG = DecisionTreeClassifier(criterion='entropy', min_samples_split=2)
#Training
start_time = time.time()
clf_dt_IG.fit(X_train, y_train)
print("The time for training Decision Tree is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt_IG.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Decision Tree: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Decision Tree:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Decision Tree :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Decision Tree:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Decision Tree is  0.00300002098083 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.90      0.33      0.49        54
#           B       0.65      0.97      0.78        68
#
# avg / total       0.76      0.69      0.65       122
#
# ===================================================================
# The accuracy on validation dataset of Decision Tree: 	0.688524590164
# Precision on validation dataset of Decision Tree:    	0.647058823529
# Recall on validation dataset of Decision Tree :      	0.970588235294
# F1 score on validation dataset of Decision Tree:     	0.776470588235

# %% [markdown]
#  Ensemble methods

# %% [markdown]
# ## Bagging Method

# %% [markdown]
# ### Bagging Method with Knn
#
#
# Using Best KNN classifier fitted the data, each built on random subsets of 50% of the samples and 50% of the features.

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
clf_dt_BGKN = BaggingClassifier(KNeighborsClassifier(n_neighbors=5),
                             max_samples=0.5, max_features=0.5)
start_time = time.time()
clf_dt_BGKN.fit(X_train, y_train)
print("The time for training Bagging Knn is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt_BGKN.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Bagging Knn: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Bagging Knn:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Bagging Knn :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Bagging Knn:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Bagging Knn is  0.0130000114441 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.83      0.56      0.67        54
#           B       0.72      0.91      0.81        68
#
# avg / total       0.77      0.75      0.74       122
#
# ===================================================================
# The accuracy on validation dataset of Bagging Knn: 	0.754098360656
# Precision on validation dataset of Bagging Knn:    	0.720930232558
# Recall on validation dataset of Bagging Knn :      	0.911764705882
# F1 score on validation dataset of Bagging Knn:     	0.805194805195

# %% [markdown]
# ### Bagging Method with DT
#
#
# Using Best DT with 'entropy', each built on random subsets of 50% of the samples and 50% of the features.

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
clf_dt_BGDT = BaggingClassifier(DecisionTreeClassifier(criterion='entropy', min_samples_split=2),
                             max_samples=0.5, max_features=0.5)
start_time = time.time()
clf_dt_BGDT.fit(X_train, y_train)
print("The time for training Bagging DT is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt_BGDT.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Bagging DT: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Bagging DT:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Bagging DT :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Bagging DT:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Bagging DT is  0.0199999809265 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.49      0.89      0.64        54
#           B       0.76      0.28      0.41        68
#
# avg / total       0.64      0.55      0.51       122
#
# ===================================================================
# The accuracy on validation dataset of Bagging DT: 	0.549180327869
# Precision on validation dataset of Bagging DT:    	0.76
# Recall on validation dataset of Bagging DT :      	0.279411764706
# F1 score on validation dataset of Bagging DT:     	0.408602150538

# %% [markdown]
# ## Random Forest
# DT with 'gini'

# %%
from sklearn.ensemble import RandomForestClassifier
clf_dt_RF = RandomForestClassifier()
#Training
start_time = time.time()
clf_dt_RF.fit(X_train, y_train)
print("The time for training Decision Tree is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt_RF.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Random Forest: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Random Forest:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Random Forest :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Random Forest:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Decision Tree is  0.0169999599457 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.56      1.00      0.72        54
#           B       1.00      0.38      0.55        68
#
# avg / total       0.81      0.66      0.63       122
#
# ===================================================================
# The accuracy on validation dataset of Random Forest: 	0.655737704918
# Precision on validation dataset of Random Forest:    	1.0
# Recall on validation dataset of Random Forest :      	0.382352941176
# F1 score on validation dataset of Random Forest:     	0.553191489362

# %% [markdown]
# ### Ada Boost
# DT with 'gini'

# %%
from sklearn.ensemble import AdaBoostClassifier
clf_dt_AD = AdaBoostClassifier()
#Training
start_time = time.time()
clf_dt_AD.fit(X_train, y_train)
print("The time for training Decision Tree is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt_AD.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Ada Boost: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Ada Boost:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Ada Boost :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Ada Boost:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Decision Tree is  0.0789999961853 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.56      1.00      0.72        54
#           B       1.00      0.38      0.55        68
#
# avg / total       0.81      0.66      0.63       122
#
# ===================================================================
# The accuracy on validation dataset of Ada Boost: 	0.655737704918
# Precision on validation dataset of Ada Boost:    	1.0
# Recall on validation dataset of Ada Boost :      	0.382352941176
# F1 score on validation dataset of Ada Boost:     	0.553191489362

# %% [markdown]
# ## Naive Bayes methods

# %%
from sklearn.naive_bayes import GaussianNB
clf_NB = GaussianNB()
#Training
start_time = time.time()
clf_NB.fit(X_train, y_train)
print("The time for training Naive Bayes is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_NB.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Naive Bayes: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Naive Bayes:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Naive Bayes :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Naive Bayes:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Naive Bayes is  0.00100016593933 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.48      0.20      0.29        54
#           B       0.57      0.82      0.67        68
#
# avg / total       0.53      0.55      0.50       122
#
# ===================================================================
# The accuracy on validation dataset of Naive Bayes: 	0.549180327869
# Precision on validation dataset of Naive Bayes:    	0.565656565657
# Recall on validation dataset of Naive Bayes :      	0.823529411765
# F1 score on validation dataset of Naive Bayes:     	0.670658682635

# %% [markdown]
# ## Linear Discriminant Analysis classifier

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
clf_dt_LDA = LinearDiscriminantAnalysis()
#Training
start_time = time.time()
clf_dt_LDA.fit(X_train, y_train)
print("The time for training Decision Tree is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt_LDA.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Linear Discriminant Analysis: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Linear Discriminant Analysis:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Linear Discriminant Analysis :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Linear Discriminant Analysis:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Decision Tree is  0.00499987602234 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.53      0.94      0.68        54
#           B       0.88      0.34      0.49        68
#
# avg / total       0.73      0.61      0.57       122
#
# ===================================================================
# The accuracy on validation dataset of Linear Discriminant Analysis: 	0.606557377049
# Precision on validation dataset of Linear Discriminant Analysis:    	0.884615384615
# Recall on validation dataset of Linear Discriminant Analysis :      	0.338235294118
# F1 score on validation dataset of Linear Discriminant Analysis:     	0.489361702128

# %% [markdown]
# ## Quadratic Discriminant Analysis classifier

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
clf_dt_QDA = QuadraticDiscriminantAnalysis()
#Training
start_time = time.time()
clf_dt_QDA.fit(X_train, y_train)
print("The time for training Decision Tree is  %s seconds " % (time.time() - start_time))

# Make a prediction
y_pred = clf_dt_QDA.predict(X_test)
print "\n==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])

print "==================================================================="
print "The accuracy on validation dataset of Quadratic Discriminant Analysis: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Quadratic Discriminant Analysis:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Quadratic Discriminant Analysis :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Quadratic Discriminant Analysis:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# The time for training Decision Tree is  0.000999927520752 seconds
#
# ===================================================================
#              precision    recall  f1-score   support
#
#           M       0.60      0.22      0.32        54
#           B       0.59      0.88      0.71        68
#
# avg / total       0.59      0.59      0.54       122
#
# ===================================================================
# The accuracy on validation dataset of Quadratic Discriminant Analysis: 	0.590163934426
# Precision on validation dataset of Quadratic Discriminant Analysis:    	0.588235294118
# Recall on validation dataset of Quadratic Discriminant Analysis :      	0.882352941176
# F1 score on validation dataset of Quadratic Discriminant Analysis:     	0.705882352941

# %% [markdown]
# # Neural Networks

# %%
import seaborn as sns
import numpy as np
from sklearn.cross_validation import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.regularizers import l2

from keras.utils import np_utils

labelsTrain = np_utils.to_categorical(y_train)
labelsTest = np_utils.to_categorical(y_test)                                              
model = Sequential()
model.add(Dense(30,
                input_shape=(10,), 
                activation="relu",
                W_regularizer=l2(0.001)))
model.add(Dropout(0.5))
model.add(Dense(2, activation="softmax"))

model.compile(loss='categorical_crossentropy',
              metrics=['accuracy'],
              optimizer='adam')
# Actual modelling
start_time = time.time()
model.fit(X_train, labelsTrain, verbose=0, batch_size=100, nb_epoch=100)
print("The time for training NN is  %s seconds " % (time.time() - start_time))
score, accuracy = model.evaluate(X_test, labelsTest, batch_size=100, verbose=0)
print("Test fraction correct (NN-Score) = {:.2f}".format(score))
print("Test fraction correct (NN-Accuracy) = {:.2f}".format(accuracy))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-44fb15e5fe52> in <module>()
#       2 import numpy as np
#       3 from sklearn.cross_validation import train_test_split
# ----> 4 from keras.models import Sequential
#       5 from keras.layers import Dense, Dropout
#       6 from keras.regularizers import l2
#
# ImportError: No module named keras.models

# %%
y_pred = model.predict_classes(X_test)

print "\n==================================================================="
print "The accuracy on validation dataset of Neural Network: \t", metrics.accuracy_score(y_test, y_pred)
print "==================================================================="
print metrics.classification_report(y_test, y_pred, target_names=['M', 'B'])
print "==================================================================="
print "The accuracy on validation dataset of Quadratic Discriminant Analysis: \t", metrics.accuracy_score(y_test, y_pred)
print "Precision on validation dataset of Quadratic Discriminant Analysis:    \t", metrics.precision_score(y_test, y_pred)
print "Recall on validation dataset of Quadratic Discriminant Analysis :      \t", metrics.recall_score(y_test, y_pred)
print "F1 score on validation dataset of Quadratic Discriminant Analysis:     \t", metrics.f1_score(y_test, y_pred)
false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
roc_auc = auc(false_positive_rate, true_positive_rate)
plt.title('Receiver Operating Characteristic')
plt.plot(false_positive_rate, true_positive_rate, 'b',
label='AUC = %0.2f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.1,1.2])
plt.ylim([-0.1,1.2])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %%
path = './valley/'
sys.path.append("./valley")
model.save_weights('valleyModelbest.hdf5',overwrite=True)

# %%
np.save('./valley/X_train', X_train)
np.save('./valley/y_train', y_train)
np.save('./valley/X_test', X_test)
np.save('./valley/y_test', y_test)
np.save('./valley/X_deploy', X_deploy)
np.save('./valley/y_deploy', y_deploy)
